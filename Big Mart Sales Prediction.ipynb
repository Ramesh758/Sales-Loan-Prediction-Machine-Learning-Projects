# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\rames\Downloads\train_v9rqX0R.csv")

# %%
df_test = pd.read_csv(r"C:\Users\rames\Downloads\test_AbJTz2l.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
df.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8513                Meat   99.9042            OUT035
# 8514              Canned   57.5904            OUT045
# 8515        Baking Goods  157.5288            OUT018
# ...

# %%
df_test.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
df.shape
# Out:
# (8523, 12)

# %%
df_test.shape
# Out:
# (5681, 11)

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df_test.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
df.describe(include='all').T
# Out:
#                             count unique                    top  freq  \
# Item_Identifier              8523   1559                  FDW13    10
# Item_Weight                7060.0    NaN                    NaN   NaN
# Item_Fat_Content             8523      5                Low Fat  5089
# Item_Visibility            8523.0    NaN                    NaN   NaN
# Item_Type                    8523     16  Fruits and Vegetables  1232
# Item_MRP                   8523.0    NaN                    NaN   NaN
# Outlet_Identifier            8523     10                 OUT027   935
# Outlet_Establishment_Year  8523.0    NaN                    NaN   NaN
# Outlet_Size                  6113      3                 Medium  2793
# Outlet_Location_Type         8523      3                 Tier 3  3350
# Outlet_Type                  8523      4      Supermarket Type1  5577
# Item_Outlet_Sales          8523.0    NaN                    NaN   NaN
#
# ...

# %%
df_test.describe(include='all').T
# Out:
#                             count unique                top  freq  \
# Item_Identifier              5681   1543              DRF48     8
# Item_Weight                4705.0    NaN                NaN   NaN
# Item_Fat_Content             5681      5            Low Fat  3396
# Item_Visibility            5681.0    NaN                NaN   NaN
# Item_Type                    5681     16        Snack Foods   789
# Item_MRP                   5681.0    NaN                NaN   NaN
# Outlet_Identifier            5681     10             OUT027   624
# Outlet_Establishment_Year  5681.0    NaN                NaN   NaN
# Outlet_Size                  4075      3             Medium  1862
# Outlet_Location_Type         5681      3             Tier 3  2233
# Outlet_Type                  5681      4  Supermarket Type1  3717
#
#                                   mean        std     min       25%       50%  \
# Item_Identifier                    NaN        NaN     NaN       NaN       NaN
# ...

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df_test.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# Item_Identifier
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: count, Length: 1559, dtype: int64
# Item_Weight
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: count, Length: 415, dtype: int64
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
# Item_Visibility
# 0.000000    526
# 0.076975      3
# 0.162462      2
# 0.076841      2
# 0.073562      2
#            ...
# 0.013957      1
# 0.110460      1
# 0.124646      1
# 0.054142      1
# 0.044878      1
# Name: count, Length: 7880, dtype: int64
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# ...

# %%
for i in df_test.columns:
    print(df_test[i].value_counts())
# Out:
# Item_Identifier
# DRF48    8
# FDZ50    8
# FDQ60    8
# FDN52    8
# FDW10    8
#         ..
# FDW49    1
# FDG38    1
# FDD38    1
# FDA15    1
# FDF04    1
# Name: count, Length: 1543, dtype: int64
# Item_Weight
# 10.500    57
# 17.600    53
# 15.600    48
# 20.250    47
# 19.350    46
#           ..
# 6.980      1
# 6.320      1
# 5.465      1
# 5.945      1
# 7.670      1
# Name: count, Length: 410, dtype: int64
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64
# Item_Visibility
# 0.000000    353
# 0.060879      2
# 0.097213      2
# 0.058461      2
# 0.058132      2
#            ...
# 0.082382      1
# 0.026175      1
# 0.155144      1
# 0.069557      1
# 0.104720      1
# Name: count, Length: 5277, dtype: int64
# Item_Type
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# ...

# %%
for i in df.columns:
    print(i, ':', df[i].nunique())
# Out:
# Item_Identifier : 1559
# Item_Weight : 415
# Item_Fat_Content : 5
# Item_Visibility : 7880
# Item_Type : 16
# Item_MRP : 5938
# Outlet_Identifier : 10
# Outlet_Establishment_Year : 9
# Outlet_Size : 3
# Outlet_Location_Type : 3
# Outlet_Type : 4
# Item_Outlet_Sales : 3493

# %%
for i in df_test.columns:
    print(i, ':', df_test[i].nunique())
# Out:
# Item_Identifier : 1543
# Item_Weight : 410
# Item_Fat_Content : 5
# Item_Visibility : 5277
# Item_Type : 16
# Item_MRP : 4402
# Outlet_Identifier : 10
# Outlet_Establishment_Year : 9
# Outlet_Size : 3
# Outlet_Location_Type : 3
# Outlet_Type : 4

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
''''''
# Out:
# ''

# %%
df1=pd.concat([df, df_test], axis=0).reset_index(drop=True)

# %%
df1.shape
# Out:
# (14204, 12)

# %%
df1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df1.tail()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 14199           FDB58         10.5          Regular         0.013496
# 14200           FDD47          7.6          Regular         0.142991
# 14201           NCO17         10.0          Low Fat         0.073529
# 14202           FDJ26         15.3          Regular         0.000000
# 14203           FDU37          9.5          Regular         0.104720
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 14199         Snack Foods  141.3154            OUT046
# 14200       Starchy Foods  169.1448            OUT018
# 14201  Health and Hygiene  118.7440            OUT045
# 14202              Canned  214.6218            OUT017
# 14203              Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# ...

# %%
df1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
df_test.shape
# Out:
# (5681, 11)

# %%
df1.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
for i in df1.columns[df1.dtypes == 'object']:
    print(i)
# Out:
# Item_Identifier
# Item_Fat_Content
# Item_Type
# Outlet_Identifier
# Outlet_Size
# Outlet_Location_Type
# Outlet_Type

# %%
for i in df1.columns[df1.dtypes!='object']:
    print(i)
# Out:
# Item_Weight
# Item_Visibility
# Item_MRP
# Outlet_Establishment_Year
# Item_Outlet_Sales

# %%
cat_col = df1.select_dtypes(include='object').columns

# %%
for i in cat_col:
    print (i)
# Out:
# Item_Identifier
# Item_Fat_Content
# Item_Type
# Outlet_Identifier
# Outlet_Size
# Outlet_Location_Type
# Outlet_Type

# %%
for i in cat_col:
    plt.figure(figsize=(15,10))
    plt.xticks(rotation=90)
    sns.countplot(x=df1[i]);

# %%
num_col = df1.select_dtypes(include=['int64','float64']).columns

# %%
for i in num_col:
    print(i)
# Out:
# Item_Weight
# Item_Visibility
# Item_MRP
# Outlet_Establishment_Year
# Item_Outlet_Sales

# %%
for i in num_col:
    plt.figure(figsize=(15,10))
    plt.xticks(rotation=90)
    sns.boxplot(x=df1[i])

# %%
for i in num_col:
    plt.figure(figsize=(15,10))
    plt.xticks(rotation=90)
    plt.hist(x=df1[i])

# %%
num_col1 = df.select_dtypes(include=['int64','float64']).columns

# %%
for i in num_col1:
    plt.figure(figsize=(15,10))
    plt.xticks(rotation=90)
    sns.scatterplot(x=df[i], y=df['Item_Outlet_Sales']);

# %%
cat_col1 = df.select_dtypes(include='object').columns

# %%
for i in cat_col1:
    plt.figure(figsize=(15,10))
    plt.xticks(rotation=90)
    sns.violinplot(x=df[i], y=df['Item_Outlet_Sales']);

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
df1.Item_Weight.mean()
# Out:
# 12.792854228644284

# %%
df1['Item_Weight'] = df1["Item_Weight"].fillna(df1['Item_Weight'].mean())

# %%
mode = df1['Outlet_Size'].mode()[0]

# %%
df1['Outlet_Size'] = df1['Outlet_Size'].fillna(mode)

# %%
df1.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
df1['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
perishable = ['Breads', 'Breakfast', 'Dairy', 'Fruits and Vegetables', 'Meat', 'Seafood']

# %%
non_perishable = ['Soft Drinks', 'Household', 'Baking Goods', 'Health and Hygiene', 'Hard Drinks', 'Canned', 'Frozen Foods']

# %%
df1['Item_Type_New'] = np.where(df1['Item_Type'] == perishable, "perishable", df1['Item_Type'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 df1['Item_Type_New'] = np.where(df1['Item_Type'] == perishable, "perishable", df1['Item_Type'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
if df1['Item_Type'] in perishable:
        df1['Item_Type'].replace(value="perishable")
else:
    df1['Item_Type'] in non_perishable:
        df1['Item_Type'].replace(value='non_perishable')
else:
    df1['Item_Type'].replace(value='not_sure')
# Out:
#   Input In [66]
#     df1['Item_Type'] in non_perishable:
#                                        ^
# SyntaxError: invalid syntax
